# %% [markdown]
# ## 📥 Twitter Sentiment Analysis
# In this lab, you will build a tweet classification system using Natural Language Processing (NLP) techniques to classify Twitter tweets as either positive or negative.
#
# 🔍 What you will do:
# - Load the dataset
# - Split the data and vectorize the tweets
# - Build and train a classification model
# - Evaluate the model’s performance
# - Test the model with new tweet examples

# %% [markdown]
# ### 🛠️ Import library

# %%
# !pip install datasets scikit-learn textblob -q
# !python -m textblob.download_corpora kagglehub
# !pip install kagglehub
# Out:
# [nltk_data] Downloading package brown to /Users/fadel/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /Users/fadel/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/fadel/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/fadel/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package conll2000 to /Users/fadel/nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     /Users/fadel/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# Finished.
# Collecting kagglehub
#   Downloading kagglehub-1.0.2-py3-none-any.whl.metadata (40 kB)
# Collecting kagglesdk<1.0,>=0.1.22 (from kagglehub)
#   Downloading kagglesdk-0.1.28-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in /opt/homebrew/Caskroom/miniconda/base/envs/pytorch-env/lib/python3.10/site-packages (from kagglehub) (24.2)
# Requirement already satisfied: pyyaml in /opt/homebrew/Caskroom/miniconda/base/envs/pytorch-env/lib/python3.10/site-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: requests in /opt/homebrew/Caskroom/miniconda/base/envs/pytorch-env/lib/python3.10/site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in /opt/homebrew/Caskroom/miniconda/base/envs/pytorch-env/lib/python3.10/site-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: protobuf in /opt/homebrew/Caskroom/miniconda/base/envs/pytorch-env/lib/python3.10/site-packages (from kagglesdk<1.0,>=0.1.22->kagglehub) (6.32.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/Caskroom/miniconda/base/envs/pytorch-env/lib/python3.10/site-packages (from requests->kagglehub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniconda/base/envs/pytorch-env/lib/python3.10/site-packages (from requests->kagglehub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Caskroom/miniconda/base/envs/pytorch-env/lib/python3.10/site-packages (from requests->kagglehub) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniconda/base/envs/pytorch-env/lib/python3.10/site-packages (from requests->kagglehub) (2025.4.26)
# Downloading kagglehub-1.0.2-py3-none-any.whl (70 kB)
# Downloading kagglesdk-0.1.28-py3-none-any.whl (230 kB)
# Installing collected packages: kagglesdk, kagglehub
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [kagglehub]/2 [kagglehub]
# Successfully installed kagglehub-1.0.2 kagglesdk-0.1.28

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

from textblob import TextBlob

import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer

# %% [markdown]
# ### 🔤📄 Data Loading

# %%
df = pd.read_csv('https://raw.githubusercontent.com/iiFadel/majal-ai-track-2026/main/labs/day4/data/tweet_sentiment.csv')

df.head()
# Out:
#                            tweet sentiment
# 0      The event starts at 5 PM.   neutral
# 1    I hate how this turned out.  negative
# 2          Fantastic experience!  positive
# 3          Fantastic experience!  positive
# 4  This is the worst thing ever!  negative

# %% [markdown]
# ### 🧮 Data Splitting & Vectorization

# %%
# 🧽 Define a function to clean the tweet text
english_stopwords = stopwords.words('english')
stemmer = PorterStemmer()

def clean_review(text):
  # Tokenize the text and filter out non-alphabetic words
  words = [word for word in word_tokenize(text) if word.isalpha()]

  # Remove stopwords and stem the remaining words
  cleaned_words = [stemmer.stem(word) for word in words if word not in english_stopwords]

  # Join the cleaned words into a single string
  text = ' '.join(cleaned_words)

  return text

# %%
# 🧹 Apply cleaning function to tweets

# %%
# 🎯 Prepare data for training


# ✂️ Split data into training and testing



# 🔢 Vectorize the text data

# %% [markdown]
# ### 🌐🤖 Model Building & Evaluation

# %%
# 🤖 Train a logistic regression classifier



# 📊 Evaluate training performance

# %%
# 📊 Evaluate test performance

# %% [markdown]
# ### 🔍🎭 Testing

# %%
# ✏️ Correct spelling errors in custom tweets


# 🔍 Define function to make sentiment prediction on custom review

# %%
# 🧪 Test the model with a custom tweets
